# %%
import pandas as pd
nba=pd.read_csv('nba.csv')
#Here we are not using squeeze or uscols type attribute and 
#by looking at the data set it is clear that it contains missing value NaN
#we are going to pre process this before actual modelling.
# nba.head()
nba.tail(10)
# Out:
#                Name       Team  Number Position   Age Height  Weight  \
# 448  Gordon Hayward  Utah Jazz    20.0       SF  26.0    6-8   226.0
# 449     Rodney Hood  Utah Jazz     5.0       SG  23.0    6-8   206.0
# 450      Joe Ingles  Utah Jazz     2.0       SF  28.0    6-8   226.0
# 451   Chris Johnson  Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453    Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454       Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455    Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0
# 456     Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0
# 457             NaN        NaN     NaN      NaN   NaN    NaN     NaN
#
#       College      Salary
# 448    Butler  15409570.0
# 449      Duke   1348440.0
# 450       NaN   2050000.0
# 451    Dayton    981348.0
# 452  Kentucky   2239800.0
# 453    Butler   2433333.0
# 454       NaN    900000.0
# 455       NaN   2900000.0
# 456    Kansas    947276.0
# 457       NaN         NaN

# %%
# nba.index
nba.shape
#it gives column and row
# nba.dtypes
# it gives object for str
# # # # # # #Below are some attributes which are made for Dataframes only
# nba.columns
# nba.axes
# it givrs index and column
# nba.info
nba.info()
#it gives full info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %% [markdown]
# # shared method and column access in pandas

# %%
import pandas as pd
rev=pd.read_csv('revenue.csv', index_col='Date')
rev.head(10)
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/16        985          122    499
# 1/2/16        738          788    534
# 1/3/16         14           20    933
# 1/4/16        730          904    885
# 1/5/16        114           71    253
# 1/6/16        936          502    497
# 1/7/16        123          996    115
# 1/8/16        935          492    886
# 1/9/16        846          954    823
# 1/10/16        54          285    216

# %%
rev.sum() #Here data is added in terms of column wise
rev.sum(axis=1)
rev.sum(axis='index')
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
# rev.sum(axis=1)
rev.sum(axis='columns')

# %%
nba=pd.read_csv('nba.csv')
nba.head()

#If i want to extract data column wise
type(nba.Salary) #Its data type is series as it is a single dimension array it works properly when there is no space in column name
# Out:
# pandas.core.series.Series

# %%
type(nba.Name)
# Out:
# pandas.core.series.Series

# %%
# nba['Name'] #It is more accurate as it works for those column also which have space in there name
nba.Name
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
# nba[['Team', 'Name']]
# select=['Team', 'Name']
nba[select]
# Out:
#                Team           Name
# 0    Boston Celtics  Avery Bradley
# 1    Boston Celtics    Jae Crowder
# 2    Boston Celtics   John Holland
# 3    Boston Celtics    R.J. Hunter
# 4    Boston Celtics  Jonas Jerebko
# ..              ...            ...
# 453       Utah Jazz   Shelvin Mack
# 454       Utah Jazz      Raul Neto
# 455       Utah Jazz   Tibor Pleiss
# 456       Utah Jazz    Jeff Withey
# 457             NaN            NaN
#
# [458 rows x 2 columns]

# %% [markdown]
# # Add new column to data frames

# %%
import pandas as pd
nba=pd.read_csv('nba.csv')
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba['Sports']='Basket Ball' #One method to add column but by this column is added at the last
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary       Sports
# 0              Texas  7730337.0  Basket Ball
# 1          Marquette  6796117.0  Basket Ball
# 2  Boston University        NaN  Basket Ball
# 3      Georgia State  1148640.0  Basket Ball
# 4                NaN  5000000.0  Basket Ball

# %%
nba=pd.read_csv('nba.csv')
#Insert method : any specific place you may add your column
nba.insert(3, column="League", value="IPL")
nba.League[[0,1]]=["Hello","test"]
nba.head()
# Out:
# C:\Users\Parekh\AppData\Local\Temp\ipykernel_14972\4069644177.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nba.League[[0,1]]=["Hello","test"]
#             Name            Team  Number League Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0  Hello       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0   test       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0    IPL       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0    IPL       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0    IPL       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# # BroadCasting operation in pandas

# %%
#Broadcasting : means to perform operation in whole series of a column
import pandas as pd
nba=pd.read_csv('nba.csv')
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
# nba['Salary'].sub(50000)
nba['Salary']-50000


# nba['Age'].add(5)
# nba['Age']+5


# nba['Weight'].mul(0.453)
# nba['Weight']*0.453



# nba["Weight in KG"]=nba['Weight']*0.453592
# nba.head()
# Out:
# 0      7680337.0
# 1      6746117.0
# 2            NaN
# 3      1098640.0
# 4      4950000.0
#          ...
# 453    2383333.0
# 454     850000.0
# 455    2850000.0
# 456     897276.0
# 457          NaN
# Name: Salary, Length: 458, dtype: float64

# %% [markdown]
# # Drops Rows with Null Values

# %%
import pandas as pd
nba=pd.read_csv('nba.csv')
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
# nba.dropna()
# nba.dropna(how='any', inplace = True)
nba.dropna(how='all', inplace=True)
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0       NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0       NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
nba.dropna(axis=1, inplace=True) #It deletes column which consists NaN
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0

# %%
nba.dropna(subset=['Salary'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15096/529997876.py in <module>
# ----> 1 nba.dropna(subset=['Salary'])
#
# d:\python\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# d:\python\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    5946             check = indices == -1
#    5947             if check.any():
# -> 5948                 raise KeyError(list(np.compress(check, subset)))
#    5949             agg_obj = self.take(indices, axis=agg_axis)
#    5950
#
# KeyError: ['Salary']

# %% [markdown]
# # fillna method for Null Values

# %%
import pandas as pd
nba=pd.read_csv('nba.csv')
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.fillna(0).head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4                  0  5000000.0

# %%
nba['Salary']
nba['Salary'].fillna(0, inplace=True)
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba['College'].fillna('No College', inplace=True)
nba
# imp
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        0.0
# 3        Georgia State  1148640.0
# 4           No College  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454         No College   900000.0
# 455         No College  2900000.0
# 456             Kansas   947276.0
# 457         No College        0.0
#
# [458 rows x 9 columns]

# %% [markdown]
# # sort_values() method in Data Frames

# %%
import pandas as pd
nba=pd.read_csv('nba.csv')
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.sort_values('Name', ascending=True).head()
# Out:
#                Name                    Team  Number Position   Age Height  \
# 152    Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 356    Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 328  Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 404   Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 312      Al Horford           Atlanta Hawks    15.0        C  30.0   6-10
#
#      Weight         College      Salary
# 152   161.0          Oregon   2250000.0
# 356   220.0         Arizona   4171680.0
# 328   210.0        Kentucky    525093.0
# 404   237.0  Michigan State   1938840.0
# 312   245.0         Florida  12000000.0

# %%
nba.sort_values('Age')
nba.sort_values('Age', ascending=True)
# Out:
#                    Name                    Team  Number Position   Age Height  \
# 226       Rashad Vaughn         Milwaukee Bucks    20.0       SG  19.0    6-6
# 122        Devin Booker            Phoenix Suns     1.0       SG  19.0    6-6
# 40   Kristaps Porzingis         New York Knicks     6.0       PF  20.0    7-3
# 401          Tyus Jones  Minnesota Timberwolves     1.0       PG  20.0    6-2
# 427     Cliff Alexander  Portland Trail Blazers    34.0       PF  20.0    6-8
# ..                  ...                     ...     ...      ...   ...    ...
# 102      Pablo Prigioni    Los Angeles Clippers     9.0       PG  39.0    6-3
# 298          Tim Duncan       San Antonio Spurs    21.0        C  40.0   6-11
# 400       Kevin Garnett  Minnesota Timberwolves    21.0       PF  40.0   6-11
# 304        Andre Miller       San Antonio Spurs    24.0       PG  40.0    6-3
# 457                 NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight      College     Salary
# 226   202.0         UNLV  1733040.0
# 122   206.0     Kentucky  2127840.0
# 40    240.0          NaN  4131720.0
# 401   195.0         Duke  1282080.0
# 427   240.0       Kansas   525093.0
# ..      ...          ...        ...
# 102   185.0          NaN   947726.0
# 298   250.0  Wake Forest  5250000.0
# 400   240.0          NaN  8500000.0
# 304   200.0         Utah   250750.0
# 457     NaN          NaN        NaN
#
# [458 rows x 9 columns]

# %%
nba.sort_values('Salary') #NaN values would arrange at the end
nba.sort_values('Salary', na_position='last')
# nba.sort_values('Salary', na_position='first')
# Out:
#                        Name                    Team  Number Position   Age  \
# 32   Thanasis Antetokounmpo         New York Knicks    43.0       SF  23.0
# 291         Orlando Johnson    New Orleans Pelicans     0.0       SG  27.0
# 130            Phil Pressey            Phoenix Suns    25.0       PG  25.0
# 135           Alan Williams            Phoenix Suns    15.0        C  23.0
# 175            Jordan McRae     Cleveland Cavaliers    12.0       SG  25.0
# ..                      ...                     ...     ...      ...   ...
# 350           Briante Weber              Miami Heat    12.0       PG  23.0
# 353           Dorell Wright              Miami Heat    11.0       SF  30.0
# 397            Axel Toupane          Denver Nuggets     6.0       SG  23.0
# 409              Greg Smith  Minnesota Timberwolves     4.0       PF  25.0
# 457                     NaN                     NaN     NaN      NaN   NaN
#
#     Height  Weight                College    Salary
# 32     6-7   205.0                    NaN   30888.0
# 291    6-5   220.0       UC Santa Barbara   55722.0
# 130   5-11   175.0               Missouri   55722.0
# 135    6-8   260.0       UC Santa Barbara   83397.0
# 175    6-5   179.0              Tennessee  111196.0
# ..     ...     ...                    ...       ...
# 350    6-2   165.0  Virginia Commonwealth       NaN
# 353    6-9   205.0                    NaN       NaN
# 397    6-7   210.0                    NaN       NaN
# 409   6-10   250.0           Fresno State       NaN
# 457    NaN     NaN                    NaN       NaN
#
# [458 rows x 9 columns]

# %% [markdown]
# # sortvalues() for multi columns in pandas

# %%
import pandas as pd
nba=pd.read_csv('nba.csv')
nba.head()

# %%
nba.sort_values(['Team', 'Name'])
# nba.sort_values(['Team', 'Name'], ascending=[True,False])

# %% [markdown]
# # rank() method in pandas

# %%
import pandas as pd
nba=pd.read_csv('nba.csv').dropna(how='all')
nba['Salary']=nba['Salary'].fillna(0).astype('int')
nba.head()

# %%
#I want to decide on the basis of salary, that whose salary is highest comes at rank 1 and so on..
nba['Salary'].rank()
# nba['Salary'][91]
nba['Salary'].rank(ascending=False).astype(int)
nba['Salary Rank']=nba['Salary'].rank(ascending=False).astype(int)
nba.sort_values(by='Salary', ascending=False)
# nba.head()

# %% [markdown]
# # Filtering DataFrames in pandas

# %%
import pandas as pd
df=pd.read_csv('employees.csv')
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.info() #at the end size is there, when we look at the output it is claer that start date and last login time data type is object, but actually they are object iof adte time same as in Senior management has object type but actually it is bool and if correct data type is not there then more memory is required
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df['Start Date']
# Out:
# 0        8/6/1993
# 1       3/31/1996
# 2       4/23/1993
# 3        3/4/2005
# 4       1/24/1998
#           ...
# 995    11/23/2014
# 996     1/31/1984
# 997     5/20/2013
# 998     4/20/2013
# 999     5/15/2012
# Name: Start Date, Length: 1000, dtype: object

# %%
# pd.to_datetime(df['Start Date'])
df['Start Date']=pd.to_datetime(df['Start Date'])

# %%
df['Last Login Time'].head()
# Out:
# 0    12:42 PM
# 1     6:53 AM
# 2    11:17 AM
# 3     1:00 PM
# 4     4:47 PM
# Name: Last Login Time, dtype: object

# %%
# pd.to_datetime(df['Last Login Time'])
df['Last Login Time']=pd.to_datetime(df['Last Login Time'])

# %%
df['Senior Management']=df['Senior Management'].astype(bool)

# %%
df['Gender']=df['Gender'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.1+ KB

# %%
#date time can be converted by attribute parse_date available in read_csv method
import pandas as pd
df=pd.read_csv('employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Gender']=df['Gender'].astype('category')
df['Senior Management']=df['Senior Management'].astype('bool')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.1+ KB

# %% [markdown]
# # Filtering a dataframe based on condition

# %%
import pandas as pd
df=pd.read_csv('employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Gender']=df['Gender'].astype('category')
df['Senior Management']=df['Senior Management'].astype('bool')
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-08-18 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-08-18 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-08-18 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2021-08-18 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2021-08-18 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
#If i want to apply condition on gender that i want only those value in gender series which are of male category
# df['Gender']
df['mask']=df['Gender']=='Male'
# df
# df[mask]
# df[df['Gender']=='Female'] #This will extract only those value in a column whose value are male

# %%
mask1=df['Team']=='Finance'
mask2=df['Gender']=='Male'

# df['Filter']=df[mask1 & mask2]
df[mask1]
df[df['Team']=='Finance']
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2021-08-18 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2021-08-18 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2021-08-18 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2021-08-18 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2021-08-18 22:47:00  114796    6.796
# ..         ...     ...        ...                 ...     ...      ...
# 907  Elizabeth  Female 1998-07-27 2021-08-18 11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19 2021-08-18 16:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08 2021-08-18 05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16 2021-08-18 08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31 2021-08-18 06:30:00   42392   19.675
#
#      Senior Management     Team   mask
# 2                False  Finance  False
# 3                 True  Finance   True
# 7                 True  Finance  False
# 14                True  Finance  False
# 46               False  Finance   True
# ..                 ...      ...    ...
# 907              False  Finance  False
# 954               True  Finance   True
# 987               True  Finance  False
# 992               True  Finance   True
# 996              False  Finance   True
#
# [102 rows x 9 columns]

# %%
mask=df['Senior Management']
# df[df['Senior Management']] #As senior management data is already in boolean so it can be done directly'
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2021-08-18 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2021-08-18 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2021-08-18 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2021-08-18 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2021-08-18 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 991       Rose  Female 2002-08-25 2021-08-18 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2021-08-18 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2021-08-18 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2021-08-18 17:47:00   98874    4.479
# 999     Albert    Male 2012-05-15 2021-08-18 18:24:00  129949   10.169
#
#      Senior Management             Team   mask
# 0                 True        Marketing   True
# 1                 True              NaN   True
# 3                 True          Finance   True
# 4                 True  Client Services   True
# 6                 True          Product  False
# ..                 ...              ...    ...
# 991               True        Marketing  False
# 992               True          Finance   True
# 993               True      Engineering  False
# 994               True        Marketing   True
# 999               True            Sales   True
#
# [535 rows x 9 columns]

# %%
mask= df['Team'] != 'Marketing'
df[mask]
# df[df['Team'] != 'Marketing'] #condition for not equal to.
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2021-08-18 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2021-08-18 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2021-08-18 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2021-08-18 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2021-08-18 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2021-08-18 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2021-08-18 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2021-08-18 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2021-08-18 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2021-08-18 18:24:00  129949   10.169
#
#      Senior Management                  Team   mask
# 1                 True                   NaN   True
# 2                False               Finance  False
# 3                 True               Finance   True
# 4                 True       Client Services   True
# 5                False                 Legal   True
# ..                 ...                   ...    ...
# 995              False          Distribution  False
# 996              False               Finance   True
# 997              False               Product   True
# 998              False  Business Development   True
# 999               True                 Sales   True
#
# [902 rows x 9 columns]

# %%
df[df['Salary']>110000]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2021-08-18 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2021-08-18 13:00:00  138705    9.340
# 5       Dennis    Male 1987-04-18 2021-08-18 01:35:00  115163   10.125
# 9      Frances  Female 2002-08-08 2021-08-18 06:51:00  139852    7.524
# 12     Brandon    Male 1980-12-01 2021-08-18 01:08:00  112807   17.492
# ..         ...     ...        ...                 ...     ...      ...
# 987     Gloria  Female 2014-12-08 2021-08-18 05:08:00  136709   10.331
# 991       Rose  Female 2002-08-25 2021-08-18 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2021-08-18 08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23 2021-08-18 06:09:00  132483   16.655
# 999     Albert    Male 2012-05-15 2021-08-18 18:24:00  129949   10.169
#
#      Senior Management                  Team   mask
# 2                False               Finance  False
# 3                 True               Finance   True
# 5                False                 Legal   True
# 9                 True  Business Development  False
# 12                True       Human Resources   True
# ..                 ...                   ...    ...
# 987               True               Finance  False
# 991               True             Marketing  False
# 992               True               Finance   True
# 995              False          Distribution  False
# 999               True                 Sales   True
#
# [322 rows x 9 columns]

# %% [markdown]
# # Filter Data Frame with AND & OR Operators

# %%
import pandas as pd
df=pd.read_csv('employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Gender']=df['Gender'].astype('category')
df['Senior Management']=df['Senior Management'].astype('bool')
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-08-18 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-08-18 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-08-18 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2021-08-18 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2021-08-18 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
mask1=df['Gender']=='Male'
mask2=df['Team']=='Marketing'

df[mask1 & mask2]

df[mask1 & mask2].head()
# Out:
#    First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0     Douglas   Male 1993-08-06 2021-08-18 12:42:00   97308    6.945
# 21    Matthew   Male 1995-09-05 2021-08-18 02:12:00  100612   13.645
# 26      Craig   Male 2000-02-27 2021-08-18 07:45:00   37598    7.757
# 74     Thomas   Male 1995-06-04 2021-08-18 14:24:00   62096   17.029
# 77    Charles   Male 2004-09-14 2021-08-18 20:13:00  107391    1.260
#
#     Senior Management       Team
# 0                True  Marketing
# 21              False  Marketing
# 26               True  Marketing
# 74              False  Marketing
# 77               True  Marketing

# %%
mask3=df['Senior Management']
mask4=df['Start Date']< '1990-01-01'

df[mask3 | mask4]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2021-08-18 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2021-08-18 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2021-08-18 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2021-08-18 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2021-08-18 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 992    Anthony    Male 2011-10-16 2021-08-18 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2021-08-18 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2021-08-18 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2021-08-18 06:30:00   42392   19.675
# 999     Albert    Male 2012-05-15 2021-08-18 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# 1                 True              NaN
# 3                 True          Finance
# 4                 True  Client Services
# 5                False            Legal
# ..                 ...              ...
# 992               True          Finance
# 993               True      Engineering
# 994               True        Marketing
# 996              False          Finance
# 999               True            Sales
#
# [653 rows x 8 columns]

# %%
mask5=df['First Name']=='Robert'
mask6=df['Team']=='Client Services'
mask7=df['Start Date']>'2016-06-01'

df[(mask5 & mask6) | mask7]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2021-08-18 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2021-08-18 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2021-08-18 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2021-08-18 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %% [markdown]
# # isin() method in pandas

# %%
import pandas as pd
df=pd.read_csv('employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Gender']=df['Gender'].astype('category')
df['Senior Management']=df['Senior Management'].astype('bool')
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.1+ KB

# %%
mask1=df['Team']=='Legal'
mask2=df['Team']=='Sales'
mask3=df['Team']=='Product'

df[mask1 | mask2 | mask3].head()
# Out:
#    First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5      Dennis    Male 1987-04-18 2022-07-08 01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17 2022-07-08 16:20:00   65476   10.012
# 11      Julie  Female 1997-10-26 2022-07-08 15:19:00  102508   12.637
# 13       Gary    Male 2008-01-27 2022-07-08 23:40:00  109831    5.831
# 15    Lillian  Female 2016-06-05 2022-07-08 06:09:00   59414    1.256
#
#     Senior Management     Team
# 5               False    Legal
# 6                True  Product
# 11               True    Legal
# 13              False    Sales
# 15              False  Product

# %%
#As in above case it is claer that it requires same code for many times so it can be deal with the help of isin() method as in this case we are able to pass multiple arguments

df['Team'].isin(['Legal', 'Sales', 'Product'])
# Out:
# 101    False
# 327    False
# 440    False
# 937    False
# 137    False
#        ...
# 902    False
# 925     True
# 946    False
# 947    False
# 951    False
# Name: Team, Length: 1000, dtype: bool

# %%
mask=df['Team'].isin(['Legal', 'Sales', 'Product'])
df[mask] #It is claer that we does not required multiple lines of asme type
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 141       Adam    Male 1990-12-24 2021-08-19 20:57:00  110194   14.727
# 610       Alan    Male 2012-02-17 2021-08-19 00:26:00   41453   10.084
# 999     Albert    Male 2012-05-15 2021-08-19 18:24:00  129949   10.169
# 970      Alice  Female 1988-09-03 2021-08-19 20:54:00   63571   15.397
# 693      Alice  Female 1995-10-16 2021-08-19 21:19:00   92799    2.782
# ..         ...     ...        ...                 ...     ...      ...
# 320        NaN  Female 2008-07-08 2021-08-19 23:40:00   62960   14.356
# 607        NaN    Male 1983-10-13 2021-08-19 23:59:00  139754   12.740
# 783        NaN     NaN 1991-04-15 2021-08-19 03:39:00  132505   13.592
# 812        NaN    Male 1994-12-13 2021-08-19 10:34:00  141311    5.478
# 925        NaN  Female 2000-08-23 2021-08-19 16:19:00   95866   19.388
#
#      Senior Management     Team
# 141               True  Product
# 610              False  Product
# 999               True    Sales
# 970               True  Product
# 693              False    Sales
# ..                 ...      ...
# 320               True    Sales
# 607               True    Sales
# 783               True  Product
# 812               True  Product
# 925               True    Sales
#
# [277 rows x 8 columns]

# %% [markdown]
# # isnull(), notnull() ,between() and duplicate() method in panda

# %%
import pandas as pd
df=pd.read_csv('employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Gender']=df['Gender'].astype('category')
df['Senior Management']=df['Senior Management'].astype('bool')
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-08-19 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-08-19 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-08-19 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2021-08-19 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2021-08-19 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
#isnull() if you want to extract null values
mask=df['Team'].isnull()
df[mask]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 2021-08-19 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 2021-08-19 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 2021-08-19 16:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 2021-08-19 14:27:00  122340    6.417
# 91         James     NaN 2005-01-26 2021-08-19 23:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22 2021-08-19 10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03 2021-08-19 01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17 2021-08-19 08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24 2021-08-19 03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14 2021-08-19 18:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31 2021-08-19 17:40:00  112117    6.338
# 367       Edward    Male 1989-08-04 2021-08-19 06:06:00   66067   10.957
# 382          NaN  Female 1996-04-18 2021-08-19 15:57:00  107024   12.182
# 434        Joyce  Female 1995-02-07 2021-08-19 07:38:00   50701   14.227
# 438        Jason    Male 1998-11-20 2021-08-19 14:54:00   69244    6.220
# 445        Chris    Male 2006-12-12 2021-08-19 01:57:00   71642    1.496
# 479      Richard    Male 1997-07-04 2021-08-19 11:47:00   47647   18.787
# 512        Wanda  Female 1993-04-06 2021-08-19 03:11:00   78883   19.695
# 513        Jimmy    Male 2013-11-19 2021-08-19 19:29:00   63549   19.624
# 520        Peter    Male 2003-02-22 2021-08-19 09:09:00   56580    8.411
# 567          NaN  Female 1980-04-01 2021-08-19 20:04:00   48141   12.605
# 573     Kimberly  Female 1981-12-30 2021-08-19 04:51:00   81800    5.435
# 580        Harry    Male 1985-01-27 2021-08-19 20:18:00   65482   18.089
# 626          NaN  Female 1997-04-13 2021-08-19 08:03:00  131755    2.930
# 634         Carl    Male 1987-03-30 2021-08-19 17:59:00   75598   19.289
# 635        Randy    Male 2000-09-27 2021-08-19 03:04:00   89831   13.047
# 647       Donald    Male 1988-04-06 2021-08-19 10:00:00  122920    5.320
# 669       Joseph     NaN 1982-03-28 2021-08-19 13:05:00   86564   11.879
# 684        Alice  Female 2016-01-21 2021-08-19 17:07:00  117787   10.485
# 706         Todd    Male 1993-07-04 2021-08-19 18:53:00  128175   18.473
# 726       Daniel    Male 2016-02-29 2021-08-19 04:04:00   77287   13.000
# 753      Antonio    Male 1999-06-06 2021-08-19 22:54:00   41928    5.478
# 774          NaN  Female 2000-06-18 2021-08-19 07:36:00  106428   10.867
# 781     Lawrence    Male 1995-07-03 2021-08-19 22:55:00   46378    9.127
# 794       Nicole  Female 2004-03-01 2021-08-19 17:17:00   44021   10.286
# 826          NaN     NaN 1988-08-01 2021-08-19 01:35:00   87103    5.665
# 850      Charles    Male 1997-09-03 2021-08-19 10:04:00  148291    6.002
# 851        Bobby    Male 1996-08-19 2021-08-19 01:16:00  147842   16.158
# 853      Mildred  Female 2007-04-06 2021-08-19 22:06:00  139284   11.390
# 855      Phillip     NaN 2003-10-20 2021-08-19 11:09:00   89700    2.277
# 864         Ryan    Male 2012-11-16 2021-08-19 13:47:00   57292    6.010
# 912          Joe    Male 1998-12-08 2021-08-19 10:28:00  126120    1.020
# 951          NaN  Female 2010-09-14 2021-08-19 05:19:00  143638    9.662
#
#      Senior Management Team
# 1                 True  NaN
# 10                True  NaN
# 23                True  NaN
# 32                True  NaN
# 91               False  NaN
# 109              False  NaN
# 139               True  NaN
# 199               True  NaN
# 258              False  NaN
# 290               True  NaN
# 314              False  NaN
# 367               True  NaN
# 382               True  NaN
# 434               True  NaN
# 438               True  NaN
# 445              False  NaN
# 479               True  NaN
# 512              False  NaN
# 513              False  NaN
# 520               True  NaN
# 567               True  NaN
# 573               True  NaN
# 580              False  NaN
# 626               True  NaN
# 634              False  NaN
# 635               True  NaN
# 647              False  NaN
# 669               True  NaN
# 684              False  NaN
# 706               True  NaN
# 726               True  NaN
# 753               True  NaN
# 774               True  NaN
# 781              False  NaN
# 794              False  NaN
# 826               True  NaN
# 850              False  NaN
# 851               True  NaN
# 853               True  NaN
# 855               True  NaN
# 864              False  NaN
# 912              False  NaN
# 951               True  NaN

# %%
mask1=df['Team'].isnull()
mask2=df['Gender'].isnull()


df [ mask1 | mask2]
# df[df['Team'].notnull()]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2021-08-19 06:53:00   61933    4.170
# 10      Louise  Female 1980-08-12 2021-08-19 09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22 2021-08-19 19:18:00   64714    4.934
# 22      Joshua     NaN 2012-03-08 2021-08-19 01:58:00   90816   18.816
# 23         NaN    Male 2012-06-14 2021-08-19 16:19:00  125792    5.042
# ..         ...     ...        ...                 ...     ...      ...
# 961    Antonio     NaN 1989-06-18 2021-08-19 21:37:00  103050    3.050
# 972     Victor     NaN 2006-07-28 2021-08-19 14:49:00   76381   11.159
# 985    Stephen     NaN 1983-07-10 2021-08-19 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2021-08-19 16:58:00   38344    3.794
# 995      Henry     NaN 2014-11-23 2021-08-19 06:09:00  132483   16.655
#
#      Senior Management             Team
# 1                 True              NaN
# 10                True              NaN
# 20                True            Legal
# 22                True  Client Services
# 23                True              NaN
# ..                 ...              ...
# 961              False            Legal
# 972               True            Sales
# 985              False            Legal
# 989              False            Legal
# 995              False     Distribution
#
# [184 rows x 8 columns]

# %%
#between()
# df['Salary'].between(60000, 70000)
df[df['Salary'].between(60000, 70000)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2021-08-19 06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17 2021-08-19 16:20:00   65476   10.012
# 10      Louise  Female 1980-08-12 2021-08-19 09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22 2021-08-19 19:18:00   64714    4.934
# 41   Christine     NaN 2015-06-28 2021-08-19 01:08:00   66582   11.308
# ..         ...     ...        ...                 ...     ...      ...
# 965  Catherine  Female 1989-09-25 2021-08-19 01:31:00   68164   18.393
# 970      Alice  Female 1988-09-03 2021-08-19 20:54:00   63571   15.397
# 974      Harry    Male 2011-08-30 2021-08-19 18:31:00   67656   16.455
# 978       Sean    Male 1983-01-17 2021-08-19 14:23:00   66146   11.178
# 998      Larry    Male 2013-04-20 2021-08-19 16:45:00   60500   11.985
#
#      Senior Management                  Team
# 1                 True                   NaN
# 6                 True               Product
# 10                True                   NaN
# 20                True                 Legal
# 41                True  Business Development
# ..                 ...                   ...
# 965              False       Client Services
# 970               True               Product
# 974               True       Client Services
# 978              False       Human Resources
# 998              False  Business Development
#
# [86 rows x 8 columns]

# %%
df['Bonus %'].between(2.0, 5.0)
df[df['Bonus %'].between(2.0, 5.0)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2021-08-19 06:53:00   61933    4.170
# 20        Lois     NaN 1995-04-22 2021-08-19 19:18:00   64714    4.934
# 40     Michael    Male 2008-10-10 2021-08-19 11:25:00   99283    2.665
# 49       Chris     NaN 1980-01-24 2021-08-19 12:13:00  113590    3.055
# 60       Paula     NaN 2005-11-23 2021-08-19 14:01:00   48866    4.271
# ..         ...     ...        ...                 ...     ...      ...
# 943      Wayne    Male 2006-09-08 2021-08-19 11:09:00   67471    2.728
# 961    Antonio     NaN 1989-06-18 2021-08-19 21:37:00  103050    3.050
# 976     Denise  Female 1992-10-19 2021-08-19 05:42:00  137954    4.195
# 989     Justin     NaN 1991-02-10 2021-08-19 16:58:00   38344    3.794
# 994     George    Male 2013-06-21 2021-08-19 17:47:00   98874    4.479
#
#      Senior Management          Team
# 1                 True           NaN
# 20                True         Legal
# 40                True  Distribution
# 49               False         Sales
# 60               False  Distribution
# ..                 ...           ...
# 943              False   Engineering
# 961              False         Legal
# 976               True         Legal
# 989              False         Legal
# 994               True     Marketing
#
# [169 rows x 8 columns]

# %%
df['Start Date'].between("1991-01-01", "1992-01-01")
df[df['Start Date'].between("1991-01-01", "1992-01-01")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 27       Scott     NaN 1991-07-11 2021-08-19 18:58:00  122367    5.218
# 75      Bonnie  Female 1991-07-02 2021-08-19 01:27:00  104897    5.118
# 88       Donna  Female 1991-11-27 2021-08-19 13:59:00   64088    6.155
# 116        NaN    Male 1991-06-22 2021-08-19 20:58:00   76189   18.988
# 148    Patrick     NaN 1991-07-14 2021-08-19 02:24:00  124488   14.837
# 166        NaN  Female 1991-07-09 2021-08-19 18:52:00   42341    7.014
# 172       Sara  Female 1991-09-23 2021-08-19 18:17:00   97058    9.402
# 220        NaN  Female 1991-06-17 2021-08-19 12:49:00   71945    5.560
# 245     Victor    Male 1991-04-11 2021-08-19 07:44:00   70817   17.138
# 277     Brenda     NaN 1991-05-29 2021-08-19 06:32:00   82439   19.062
# 313       Judy  Female 1991-07-01 2021-08-19 02:33:00  109510   13.457
# 328     Samuel    Male 1991-12-19 2021-08-19 02:54:00   76076    5.319
# 339    Michael    Male 1991-11-22 2021-08-19 12:57:00   98753   16.443
# 537    Cynthia  Female 1991-09-14 2021-08-19 13:08:00   51633   13.472
# 552    Barbara  Female 1991-09-02 2021-08-19 15:41:00  127297   11.905
# 603       Carl     NaN 1991-10-26 2021-08-19 08:11:00  100888   12.490
# 639     Amanda     NaN 1991-08-11 2021-08-19 14:15:00   46665   19.391
# 704     Thomas    Male 1991-09-07 2021-08-19 09:51:00   65251   11.211
# 725     Jeremy    Male 1991-05-19 2021-08-19 13:40:00  131513    1.876
# 766     Justin    Male 1991-07-25 2021-08-19 00:45:00  112975    9.699
# 771      Peter    Male 1991-05-22 2021-08-19 01:39:00  102577   12.026
# 783        NaN     NaN 1991-04-15 2021-08-19 03:39:00  132505   13.592
# 891    Timothy    Male 1991-08-25 2021-08-19 10:37:00   92587    8.475
# 895     Janice     NaN 1991-11-19 2021-08-19 18:02:00  139791   16.968
# 909     Donald    Male 1991-08-01 2021-08-19 02:25:00   61999    6.466
# 923      Irene     NaN 1991-02-28 2021-08-19 22:23:00  135369    4.380
# 989     Justin     NaN 1991-02-10 2021-08-19 16:58:00   38344    3.794
#
#      Senior Management                  Team
# 27               False                 Legal
# 75                True       Human Resources
# 88                True                 Legal
# 116               True                 Legal
# 148               True                 Sales
# 166               True                 Sales
# 172              False               Finance
# 220               True             Marketing
# 245              False           Engineering
# 277              False                 Sales
# 313               True                 Legal
# 328               True               Finance
# 339               True       Human Resources
# 537               True  Business Development
# 552               True               Product
# 603               True  Business Development
# 639               True       Client Services
# 704              False          Distribution
# 725               True               Finance
# 766              False       Human Resources
# 771               True               Product
# 783               True               Product
# 891              False               Finance
# 895              False  Business Development
# 909              False               Product
# 923              False  Business Development
# 989              False                 Legal

# %%
#duplicate() method
df.sort_values('First Name', inplace=True)
# df['First Name']=df.sort_values('First Name')
df['First Name']
# Out:
# 101    Aaron
# 327    Aaron
# 440    Aaron
# 937    Aaron
# 137     Adam
#        ...
# 902      NaN
# 925      NaN
# 946      NaN
# 947      NaN
# 951      NaN
# Name: First Name, Length: 1000, dtype: object

# %%
df['First Name'].duplicated(keep='last') #it says that first value is not duplicate as in parameter it has keep=first you may change it to last also
# Out:
# 101     True
# 327     True
# 440     True
# 937    False
# 137     True
#        ...
# 902     True
# 925     True
# 946     True
# 947     True
# 951    False
# Name: First Name, Length: 1000, dtype: bool

# %%
 df[df['First Name'].duplicated(keep=False)].head()

# %%
mask = ~ df[df['First Name'].duplicated(keep=False)].head() #reverse operation of duplicate so ir gives unique value from data sets

# %%
#drop duplicate method\
len(df)

# %%
len(df.drop_duplicates())

# %%
df.drop_duplicates(subset=['First Name'], keep='first')
len( df.drop_duplicates(subset=['First Name'], keep='first'))

# %%
df.drop_duplicates(subset=['First Name', 'Team'], keep='last').head()

# %% [markdown]
# # Retrieve row values using loc() method in pandas

# %%
import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
# short by alphabets
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.loc['Casino Royale']
# to extract a row
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %%
bond.loc['GoldenEye']
# Out:
# Year                            1995
# Actor                 Pierce Brosnan
# Director             Martin Campbell
# Box Office                     518.5
# Budget                          76.9
# Bond Actor Salary                5.1
# Name: GoldenEye, dtype: object

# %%
bond.loc['Casino Royale']
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %%
# bond.loc['Diamonds are Forever': 'Moonracker']
# bond.loc['GoldenEye':]
bond.loc[: "On Her Majesty's Secret Services"]
# Out:
#                                  Year           Actor         Director  \
# Film
# A View to a Kill                 1985     Roger Moore        John Glen
# Casino Royale                    2006    Daniel Craig  Martin Campbell
# Casino Royale                    1967     David Niven       Ken Hughes
# Diamonds Are Forever             1971    Sean Connery     Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan     Lee Tamahori
# Dr. No                           1962    Sean Connery    Terence Young
# For Your Eyes Only               1981     Roger Moore        John Glen
# From Russia with Love            1963    Sean Connery    Terence Young
# GoldenEye                        1995  Pierce Brosnan  Martin Campbell
# Goldfinger                       1964    Sean Connery     Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton        John Glen
# Live and Let Die                 1973     Roger Moore     Guy Hamilton
# Moonraker                        1979     Roger Moore    Lewis Gilbert
# Never Say Never Again            1983    Sean Connery   Irvin Kershner
# Octopussy                        1983     Roger Moore        John Glen
# On Her Majesty's Secret Service  1969  George Lazenby    Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                      275.2    54.5                9.1
# Casino Royale                         581.5   145.3                3.3
# Casino Royale                         315.0    85.0                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                       465.4   154.2               17.9
# Dr. No                                448.8     7.0                0.6
# For Your Eyes Only                    449.4    60.2                NaN
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                             518.5    76.9                5.1
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                       250.9    56.7                7.9
# Live and Let Die                      460.3    30.8                NaN
# Moonraker                             535.0    91.5                NaN
# Never Say Never Again                 380.0    86.0                NaN
# Octopussy                             373.8    53.9                7.8
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %%
bond.loc[["For Your Eyes Only", "Live and Let Die"]]
# Out:
#                     Year        Actor      Director  Box Office  Budget  \
# Film
# For Your Eyes Only  1981  Roger Moore     John Glen       449.4    60.2
# Live and Let Die    1973  Roger Moore  Guy Hamilton       460.3    30.8
#
#                     Bond Actor Salary
# Film
# For Your Eyes Only                NaN
# Live and Let Die                  NaN

# %% [markdown]
# #  Retrieve row values using iloc() method in pandas

# %%
import pandas as pd
bond=pd.read_csv('jamesbond.csv')
bond.head(16)
# Out:
#                                Film  Year           Actor        Director  \
# 0                            Dr. No  1962    Sean Connery   Terence Young
# 1             From Russia with Love  1963    Sean Connery   Terence Young
# 2                        Goldfinger  1964    Sean Connery    Guy Hamilton
# 3                       Thunderball  1965    Sean Connery   Terence Young
# 4                     Casino Royale  1967     David Niven      Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery   Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby   Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery    Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore    Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore    Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore   Lewis Gilbert
# 11                        Moonraker  1979     Roger Moore   Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore       John Glen
# 13            Never Say Never Again  1983    Sean Connery  Irvin Kershner
# 14                        Octopussy  1983     Roger Moore       John Glen
# 15                 A View to a Kill  1985     Roger Moore       John Glen
#
#     Box Office  Budget  Bond Actor Salary
# 0        448.8     7.0                0.6
# 1        543.8    12.6                1.6
# 2        820.4    18.6                3.2
# 3        848.1    41.9                4.7
# 4        315.0    85.0                NaN
# 5        514.2    59.9                4.4
# 6        291.5    37.3                0.6
# 7        442.5    34.7                5.8
# 8        460.3    30.8                NaN
# 9        334.0    27.7                NaN
# 10       533.0    45.1                NaN
# 11       535.0    91.5                NaN
# 12       449.4    60.2                NaN
# 13       380.0    86.0                NaN
# 14       373.8    53.9                7.8
# 15       275.2    54.5                9.1

# %%
# bond.loc[15]
bond.iloc[15]
# it extract a specific row
# Out:
# Film                 A View to a Kill
# Year                             1985
# Actor                     Roger Moore
# Director                    John Glen
# Box Office                      275.2
# Budget                           54.5
# Bond Actor Salary                 9.1
# Name: 15, dtype: object

# %%
bond.iloc[[15,20]]
# bond.iloc[:4]
# bond.iloc[4:8]
# bond.iloc[0:20:2]

# MOST IMP
# Out:
#                        Film  Year           Actor       Director  Box Office  \
# 15         A View to a Kill  1985     Roger Moore      John Glen       275.2
# 20  The World Is Not Enough  1999  Pierce Brosnan  Michael Apted       439.5
#
#     Budget  Bond Actor Salary
# 15    54.5                9.1
# 20   158.3               13.5

# %% [markdown]
# # Retrive row values using ix() methods in pandas

# %%
# In case of ix it has both the capability of loc and iloc
import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.loc['GoldenEye']
bond.ix['GoldenEye']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22492/4054749594.py in <module>
#       1 bond.loc['GoldenEye']
# ----> 2 bond.ix['GoldenEye']
#
# d:\python\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5476         ):
#    5477             return self[name]
# -> 5478         return object.__getattribute__(self, name)
#    5479
#    5480     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %%
bond.ix[[ 'Moonraker', 'Spectre']]

# %%
'Spectre' in bond.index
'Sacred Bond' in bond.index
bond.index
bond.values

# %%
bond.ix[0] #It shows that ix will be taken data as loc and iloc both

# %% [markdown]
# # Second argument of iloc, loc and ix methods

# %%
import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()

# %%
bond.loc['Moonraker', 'Actor']
# bond.loc['Moonraker', 'Director']
# bond.loc['Moonraker', 'Actor':'Budget']
bond.loc['Moonraker', ['Year', 'Director', 'Budget']]
# #Similarly we can use it with iloc and ix

# %% [markdown]
# # Set new values or a specific cell or Row in pandas

# %%
import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.ix['Dr. No']

# %%
#For eg i want to change the name of the actor
bond.ix['Dr. No', 'Actor']='Sir Sean Connery'
bond.ix['Dr. No', 'Actor']

# %%
bond.ix['Dr. No', ['Box Office', 'Budget', 'Bond Actor Salary']]=[470, 9, 6]

# %%
bond.ix['Dr. No']

# %% [markdown]
# # Set Multiple values in DataFrames in pandas

# %%
import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
mask=bond['Actor']=='Sean Connery'
bond[mask]

# %%
bond[mask]['Actor']='Sir Sean Connery'

# %%
df2=bond[mask]
df2['Actor']='Sir Sean Connery'
df2
# Out:
# C:\Users\Parekh\AppData\Local\Temp/ipykernel_22492/108644777.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2=bond[mask]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22492/108644777.py in <module>
# ----> 1 df2=bond[mask]
#       2 df2['Actor']='Sir Sean Connery'
#       3 df2
#
# d:\python\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3444         # Do we have a (boolean) 1d indexer?
#    3445         if com.is_bool_indexer(key):
# -> 3446             return self._getitem_bool_array(key)
#    3447
#    3448         # We are left with two options: a single key, and a collection of keys,
#
# d:\python\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    3497         # check_bool_indexer will throw exception if Series key cannot
#    3498         # be reindexed to match DataFrame rows
# -> 3499         key = check_bool_indexer(self.index, key)
#    3500         indexer = key.nonzero()[0]
#    3501         return self._take_with_is_copy(indexer, axis=0)
#
# d:\python\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(index, key)
#    2386         mask = isna(result._values)
#    2387         if mask.any():
# -> 2388             raise IndexingError(
#    2389                 "Unalignable boolean Series provided as "
#    2390                 "indexer (index of the boolean Series and of "
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
bond

# %%
bond.ix[mask]
bond.ix[mask,'Actor']='Sir Sean Connery'
bond

# %% [markdown]
# # Rename Index Labels or Columns in pandas

# %%
import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()

# %%
bond.rename(columns={'Year':'Release date', 'Box Office' : 'Revenue'}, inplace=True)
bond.head()
# Out:
#                       Release date           Actor         Director  Revenue  \
# Film
# A View to a Kill              1985     Roger Moore        John Glen    275.2
# Casino Royale                 2006    Daniel Craig  Martin Campbell    581.5
# Casino Royale                 1967     David Niven       Ken Hughes    315.0
# Diamonds Are Forever          1971    Sean Connery     Guy Hamilton    442.5
# Die Another Day               2002  Pierce Brosnan     Lee Tamahori    465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.rename(index={'Dr. No':'Doctor No', 'GoldenEye':'Golden Eye','The World Is Not Enough': 'Best Bond Movie'})

# %% [markdown]
# # Query Methods in Pandas

# %%
#Query methods only applys when all the column are strings and no space in between columns name

import pandas as pd
bond=pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.columns=[column_names.replace(" ",  "_") for column_names in bond.columns]
bond.head()
# Out:
#                       Year           Actor         Director  Box_Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond_Actor_Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.query('Actor=="Sean Connery"')
# Out:
#                        Year         Actor        Director  Box_Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond_Actor_Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# You Only Live Twice                  4.4

# %%
bond.query("Director=='Terence Young'")
# Out:
#                        Year         Actor       Director  Box_Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
#
#                        Bond_Actor_Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Thunderball                          4.7

# %%
bond.query("Actor != 'Roger Moore'")
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Thunderball                      1965    Sean Connery       Terence Young
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
#
#                                  Box_Office  Budget  Bond_Actor_Salary
# Film
# Casino Royale                         581.5   145.3                3.3
# Casino Royale                         315.0    85.0                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                       465.4   154.2               17.9
# Dr. No                                448.8     7.0                0.6
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                             518.5    76.9                5.1
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                       250.9    56.7                7.9
# Never Say Never Again                 380.0    86.0                NaN
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Quantum of Solace                     514.2   181.4                8.1
# Skyfall                               943.5   170.2               14.5
# Spectre                               726.7   206.3                NaN
# The Living Daylights                  313.5    68.8                5.2
# The World Is Not Enough               439.5   158.3               13.5
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                   463.2   133.9               10.0
# You Only Live Twice                   514.2    59.9                4.4

# %%
bond.query("Box_Office>600")
# Out:
#              Year         Actor       Director  Box_Office  Budget  \
# Film
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Spectre      2015  Daniel Craig     Sam Mendes       726.7   206.3
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
#
#              Bond_Actor_Salary
# Film
# Goldfinger                 3.2
# Skyfall                   14.5
# Spectre                    NaN
# Thunderball                4.7

# %%
bond.query("Actor=='Roger Moore' & Director=='John Glen'")
# Out:
#                     Year        Actor   Director  Box_Office  Budget  \
# Film
# A View to a Kill    1985  Roger Moore  John Glen       275.2    54.5
# For Your Eyes Only  1981  Roger Moore  John Glen       449.4    60.2
# Octopussy           1983  Roger Moore  John Glen       373.8    53.9
#
#                     Bond_Actor_Salary
# Film
# A View to a Kill                  9.1
# For Your Eyes Only                NaN
# Octopussy                         7.8
